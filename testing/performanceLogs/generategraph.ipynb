# %%
# https://cmdlinetips.com/2019/10/how-to-make-a-plot-with-two-different-y-axis-in-python-with-matplotlib/
# import pandas
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Carpentries link for gapminder data
data_url = 'http://bit.ly/2cLzoxH'
#load gapminder data from url as pandas dataframe
gapminder = pd.read_csv(data_url)
print(gapminder.head(3))
# Out:
#        country  year         pop continent  lifeExp   gdpPercap
# 0  Afghanistan  1952   8425333.0      Asia   28.801  779.445314
# 1  Afghanistan  1957   9240934.0      Asia   30.332  820.853030
# 2  Afghanistan  1962  10267083.0      Asia   31.997  853.100710

# %%
gapminder_us = gapminder[gapminder.country=="United States"]

# %%
# create figure and axis objects with subplots()
fig,ax=plt.subplots()
ax.plot(gapminder_us.year, gapminder_us.lifeExp, marker="o")
ax.set_xlabel("year")
ax.set_ylabel("lifeExp")
ax.plot(gapminder_us.year, gapminder_us["gdpPercap"], marker="o")
plt.show()

# %%
# create figure and axis objects with subplots()
fig,ax = plt.subplots()
# make a plot
ax.plot(gapminder_us.year, gapminder_us.lifeExp, color="red", marker="o")
# set x-axis label
ax.set_xlabel("year",fontsize=14)
# set y-axis label
ax.set_ylabel("lifeExp",color="red",fontsize=14)
# Out:
# Text(0, 0.5, 'lifeExp')

# %%
# twin object for two different y-axis on the sample plot
ax2=ax.twinx()
# make a plot with different y-axis using second axis object
ax2.plot(gapminder_us.year, gapminder_us["gdpPercap"],color="blue",marker="o")
ax2.set_ylabel("gdpPercap",color="blue",fontsize=14)
plt.show()
# save the plot as a file
fig.savefig('two_different_y_axis_for_single_python_plot_with_twinx.jpg',
            format='jpeg',
            dpi=100,
            bbox_inches='tight')

# %%
# my examples
df = pd.read_csv('C:\\Users\\Eduardo\\Documents\\2021\\UNICAMP\\dissertation2022\\Testing\\aries-performancelocalcoma.csv')

print(df.to_string())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-10-bad58eb2bf17> in <module>
#       1 # my examples
# ----> 2 df = pd.read_csv('C:\\Users\\Eduardo\\Documents\\2021\\UNICAMP\\dissertation2022\\Testing\\aries-performancelocalcoma.csv')
#       3
#       4 print(df.to_string())
#
# ...

# %%
import matplotlib.pyplot as plt

# %%
df.plot(x="txNumber",y=["Throughput (TPS)", "Max Latency(s)"])

# %%
fig, ax = plt.subplots(figsize=(12,5))
h1=df.iloc[0, 1]
h2=df.iloc[0, 3]
h3=df.iloc[0, 4]
x='Hyperledger Fabric Performance (workers='+str(h1)+', transaction load='+str(h2)+', assets='+str(h3)+')'
ax.set_title(x)
ax2=ax.twinx()
df.plot(x='workers-number', y='Throughput (TPS)', ax=ax, alpha=0.8, color='black')
color='tab:green'
#ax2.set_ylabel('Max Latency (s)',color=color)
df.plot(x='workers-number',y='Avg Latency(s)',ax=ax2,linestyle = 'dashed',alpha=0.8, color='black')
ax.set_xlabel('Number of workers', fontsize=12)
ax.get_legend().remove()
ax.set_ylabel('Throughput (TPS)', fontsize=12)
ax2.set_ylabel('Avg Latency (s)', fontsize=12)
ax2.get_legend().remove()
plt.tight_layout()
plt.show()
fig.savefig('C:\\Users\\Eduardo\\Documents\\2021\\UNICAMP\\Dissertacao\\Testing\\HF_TPS_workers_t2_a10.jpg',
            format='jpeg',
            dpi=100,
            bbox_inches='tight')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Avg Latency(s)'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-23-6c723ccc08aa> in <module>
#       9 color='tab:green'
# ...

# %%
fig, ax = plt.subplots(figsize=(12,5))
#h1=df.iloc[0, 1]
h2=df.iloc[0, 3]
h3=df.iloc[0, 4]
x='Hyperledger Fabric Performance (transaction load='+str(h2)+', assets='+str(h3)+')'
ax.set_title(x)
ax2=ax.twinx()
df.plot(x='workers-number', y='Throughput (TPS)', ax=ax, alpha=0.8, color='black')
color='tab:green'
#ax2.set_ylabel('Max Latency (s)',color=color)
df.plot(x='workers-number',y='Max Latency(s)',ax=ax2,linestyle = 'dashed',alpha=0.8, color='black')
ax.set_xlabel('Number of workers', fontsize=12)
ax.get_legend().remove()
ax.set_ylabel('Throughput (TPS)', fontsize=12)
ax2.set_ylabel('Max Latency (s)', fontsize=12)
ax2.get_legend().remove()
plt.tight_layout()
plt.show()
fig.savefig('C:\\Users\\Eduardo\\Documents\\2021\\UNICAMP\\Dissertacao\\Testing\\HF_TPS_workers_t2_a10.jpg',
            format='jpeg',
            dpi=100,
            bbox_inches='tight')

# %%
fig, ax = plt.subplots(figsize=(12,5))
#h1=df.iloc[0, 1]
h2=df.iloc[0, 3]
h3=df.iloc[0, 4]
x='Hyperledger Aries Performance (number of credentials ='+str(h3)+'), testnet: von-network (local network)'
ax.set_title(x)
ax2=ax.twinx()
df.plot(x='txNumber', y='Throughput (TPS)', ax=ax, alpha=0.8, color='black')
color='tab:green'
#ax2.set_ylabel('Max Latency (s)',color=color)
df.plot(x='txNumber',y='Avg Latency (s)',ax=ax2,linestyle = 'dashed',alpha=0.8, color='black')
ax.set_xlabel('Number of concurrent exchanges', fontsize=12)
ax.get_legend().remove()
ax.set_ylabel('Throughput (TPS)', fontsize=12)
ax2.set_ylabel('Avg Latency (s)', fontsize=12)
ax2.get_legend().remove()
plt.tight_layout()
plt.show()
fig.savefig('C:\\Users\\Eduardo\\Documents\\2021\\UNICAMP\\Dissertacao\\Testing\\aries-performancelocal.jpg',
            format='jpeg',
            dpi=100,
            bbox_inches='tight')

# %% [markdown]
# # Graphics dissertation

# %%
# https://cmdlinetips.com/2019/10/how-to-make-a-plot-with-two-different-y-axis-in-python-with-matplotlib/
# import pandas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# my examples
df1 = pd.read_csv('C:\\Users\\Eduardo\\Documents\\2022\\UNICAMP\\dissertation2022\\test\\Performance\\ariesLedgerLocal.csv')

print(df1.to_string())
# Out:
#    threads  credentials  total time  latency   TPS  startup dur  connect  publish  total runtime       VM  timeout ledger
# 0       50           10       25.55     2.55  0.39        69.24     2.74    74.50         177.24  google1      120  local
# 1       50           50      142.01     2.84  0.35        76.47     1.98    26.49         252.50  google1      120  local
# 2       50          100      253.53     2.54  0.39        72.72     4.55    89.96         426.28  google1      120  local
# 3       50          250      600.76     2.40  0.42        88.97     2.02    26.78         723.99  google1      120  local
# 4       50          500     1182.25     2.36  0.42        71.01     1.71    46.49        1306.49  google1      120  local
# 5       50         1000     2455.75     2.46  0.41        67.01     1.71    41.95        2571.45  google1      120  local
# 6       50         2000     5031.28     2.52  0.40        76.76     1.70   159.26        5274.25  google1      120  local
# ...

# %%
df2 = pd.read_csv('C:\\Users\\Eduardo\\Documents\\2022\\UNICAMP\\dissertation\\test\\Performance\\ariesLedgerTest.csv')

print(df2.to_string())
# Out:
#    threads  credentials  total time  latency   TPS  startup dur  connect  publish  total runtime       VM  timeout ledger
# 0       50           10        3.73     0.37  2.68        13.11     0.28    22.65          41.81  google1      120   test
# 1       50           50       16.18     0.32  3.09        11.10     0.26    10.45          40.15  google1      120   test
# 2       50          100       29.77     0.30  3.36        11.09     0.25     9.69          53.04  google1      120   test
# 3       50          250      232.00     0.93  1.08        11.09     0.26    25.15         272.09  google1      120   test
# 4       50          500      547.41     1.09  0.91        11.60     0.26    20.72         583.59  google1      120   test
# 5       50         1000     1184.52     1.18  0.84        12.11     0.31     8.10        1208.59  google1      120   test
# 6       50         2000     2609.73     1.30  0.77        11.60     0.25    17.23        2641.83  google1      120   test
# ...

# %%
df3 = pd.read_csv('C:\\Users\\Eduardo\\Documents\\2022\\UNICAMP\\dissertation\\test\\Performance\\ariesLedgerProd.csv')

print(df3.to_string())
# Out:
#    threads  credentials  total time  latency   TPS  startup dur  connect  publish  total runtime       VM  timeout ledger
# 0       50           10        3.40     0.34  2.94        12.10     0.26    18.12          36.16  google1      120   prod
# 1       50           50       15.66     0.31  3.19        11.09     0.24     5.38          34.50  google1      120   prod
# 2       50          100       29.11     0.29  3.43        11.10     0.25     5.47          48.10  google1      120   prod
# 3       50          250      220.40     0.88  1.13        11.60     0.25    21.28         256.42  google1      120   prod
# 4       50          500      486.51     0.97  1.03        11.60     0.23     6.56         507.94  google1      120   prod
# 5       50         1000     1225.77     1.23  0.82        11.61     0.27    26.70        1269.28  google1      120   prod
# 6       50         2000     2552.90     1.28  0.78        11.59     0.27    28.28        2596.69  google1      120   prod
# ...

# %%
df1
# Out:
#    threads  credentials  total time  latency   TPS  startup dur  connect  \
# 0       50           10       25.55     2.55  0.39        69.24     2.74
# 1       50           50      142.01     2.84  0.35        76.47     1.98
# 2       50          100      253.53     2.54  0.39        72.72     4.55
# 3       50          250      600.76     2.40  0.42        88.97     2.02
# 4       50          500     1182.25     2.36  0.42        71.01     1.71
# 5       50         1000     2455.75     2.46  0.41        67.01     1.71
# 6       50         2000     5031.28     2.52  0.40        76.76     1.70
# 7       50         3000     7154.51     2.38  0.42        70.21     1.55
# 8       50         4000     9372.97     2.34  0.43        69.53     1.70
# 9       50         5000    11818.50     2.36  0.42        67.29     1.45
#
#    publish  total runtime       VM  timeout ledger
# 0    74.50         177.24  google1      120  local
# 1    26.49         252.50  google1      120  local
# ...

# %%
fig, ax = plt.subplots(figsize=(12,5))
h1=df1.iloc[0, 0]
#h2=df1.iloc[0, 3]
#h3=df1.iloc[0, 4]
x='Hyperledger Aries Performance (number of threads ='+str(h1)+'), testnet: von-network (local network)'
ax.set_title(x)
ax2=ax.twinx()
df1.plot(x='credentials', y='TPS', ax=ax, alpha=0.8, color='green')
color='tab:green'
#ax2.set_ylabel('Max Latency (s)',color=color)
df1.plot(x='credentials',y='latency',ax=ax2,linestyle = 'dashed',alpha=0.8, color='blue')
ax.set_xlabel('Number of credentials', fontsize=12)
ax.get_legend().remove()
ax.set_ylabel('Credentials per Second (TPS)', fontsize=12)
ax2.set_ylabel('Latency (s)', fontsize=12)
ax2.get_legend().remove()
plt.tight_layout()
# Shrink current axis's height by 10% on the bottom
box = ax.get_position()
ax.set_position([box.x0, box.y0 + box.height * 0.1,
                 box.width, box.height * 0.9])

# Put a legend below current axis
ax.legend(loc='upper center', bbox_to_anchor=(0.9, 0.5),
          fancybox=True, shadow=True, ncol=5)
ax2.legend(loc='upper center', bbox_to_anchor=(0.8, 0.5),
          fancybox=True, shadow=True, ncol=5)
plt.show()
fig.savefig('C:\\Users\\Eduardo\\Documents\\2021\\UNICAMP\\Dissertacao\\Testing\\aries-ledgerlocal.jpg',
            format='jpeg',
            dpi=100,
            bbox_inches='tight')

# %%
fig, ax = plt.subplots(figsize=(12,5))
h1=df2.iloc[0, 0]
#h2=df1.iloc[0, 3]
#h3=df1.iloc[0, 4]
x='Hyperledger Aries Performance (number of threads ='+str(h1)+'), testnet: bcovrin (test)'
ax.set_title(x)
ax2=ax.twinx()
df2.plot(x='credentials', y='TPS', ax=ax, alpha=0.8, color='green')
color='tab:green'
#ax2.set_ylabel('Max Latency (s)',color=color)
df2.plot(x='credentials',y='latency',ax=ax2,linestyle = 'dashed',alpha=0.8, color='blue')
ax.set_xlabel('Number of credentials', fontsize=12)
ax.get_legend().remove()
ax.set_ylabel('Credentials per Second (TPS)', fontsize=12)
ax2.set_ylabel('Latency (s)', fontsize=12)
ax2.get_legend().remove()
plt.tight_layout()
# Put a legend below current axis
ax.legend(loc='upper center', bbox_to_anchor=(0.9, 0.5),
          fancybox=True, shadow=True, ncol=5)
ax2.legend(loc='upper center', bbox_to_anchor=(0.8, 0.5),
          fancybox=True, shadow=True, ncol=5)
plt.show()
fig.savefig('C:\\Users\\Eduardo\\Documents\\2021\\UNICAMP\\Dissertacao\\Testing\\aries-ledgerbcovrin-test.jpg',
            format='jpeg',
            dpi=100,
            bbox_inches='tight')

# %%
fig, ax = plt.subplots(figsize=(12,5))
h1=df2.iloc[0, 0]
#h2=df1.iloc[0, 3]
#h3=df1.iloc[0, 4]
x='Hyperledger Aries Performance (number of threads ='+str(h1)+'), testnet: bcovrin (production)'
ax.set_title(x)
ax2=ax.twinx()
df3.plot(x='credentials', y='TPS', ax=ax, alpha=0.8, color='green')
color='tab:green'
#ax2.set_ylabel('Max Latency (s)',color=color)
df3.plot(x='credentials',y='latency',ax=ax2,linestyle = 'dashed',alpha=0.8, color='blue')
ax.set_xlabel('Number of credentials', fontsize=12)
ax.get_legend().remove()
ax.set_ylabel('Credentials per Second (TPS)', fontsize=12)
ax2.set_ylabel('Latency (s)', fontsize=12)
ax2.get_legend().remove()
plt.tight_layout()
# Put a legend below current axis
ax.legend(loc='upper center', bbox_to_anchor=(0.9, 0.5),
          fancybox=True, shadow=True, ncol=5)
ax2.legend(loc='upper center', bbox_to_anchor=(0.8, 0.5),
          fancybox=True, shadow=True, ncol=5)
plt.show()
fig.savefig('C:\\Users\\Eduardo\\Documents\\2021\\UNICAMP\\Dissertacao\\Testing\\aries-ledgerbcovrin-production.jpg',
            format='jpeg',
            dpi=100,
            bbox_inches='tight')

# %% [markdown]
# ## Hyperleder Aries Node Increase, from 4 nodes to 7 nodes

# %%
# my examples
df4 = pd.read_csv('C:\\Users\\Eduardo\\Documents\\2022\\UNICAMP\\dissertation2022\\test\\Performance\\ariesLedgerLocal4and7nodes2.txt')

print(df4.to_string())
# Out:
#    threads  credentials  total time  latency   TPS  startup dur  connect  publish  total runtime       VM  timeout ledger  total2 time2  latency2  TPS2  startup dur2  connect2  publish2  total runtime2      VM2  timeout2 ledger2                                                                                   other timer
# 0       50           10       25.55     2.55  0.39        69.24     2.74    74.50         177.24  google1      120  local         29.92      2.99  0.33         66.70      1.75    138.30          241.07  google2       400   local   AGENT.PY.START_TIMEOUT=400 PERFORMANCE.PY.FABER.DETECT_CONNECTION 120 AGENT.UPDATE_CREDS 90
# 1       50           50      142.01     2.84  0.35        76.47     1.98    26.49         252.50  google1      120  local        136.22      2.72  0.37         67.41      1.74     16.80          226.53  google2       400   local  AGENT.PY.START_TIMEOUT=400 PERFORMANCE.PY.FABER.DETECT_CONNECTION 120 AGENT.UPDATE_CREDS 120
# ...

# %%
h4=df4.iloc[0, 0]
h4
# Out:
# 50

# %%
fig, ax = plt.subplots(figsize=(12,5))
h4=df4.iloc[0, 0]
#h2=df1.iloc[0, 3]
#h3=df1.iloc[0, 4]
x='Hyperledger Aries Performance (number of threads ='+str(h4)+'), testnet: von-network (local network) 4 to 7 nodes'
ax.set_title(x)
ax2=ax.twinx()
df4.plot(x='credentials', y='TPS', ax=ax, alpha=0.8, color='black',label='TPS 4 nodes',linewidth=1.0)
df4.plot(x='credentials', y='TPS2', ax=ax, alpha=0.8, color='black',label='TPS 7 nodes',linewidth=2.0)
color='tab:green'
#ax2.set_ylabel('Max Latency (s)',color=color)
df4.plot(x='credentials',y='latency',ax=ax2,linestyle = 'dashed',alpha=0.8, color='black',label='Lat 4 nodes',linewidth=1.0)
df4.plot(x='credentials',y='latency2',ax=ax2,linestyle = 'dashed',alpha=0.8, color='black',label='Lat 7 nodes',linewidth=2.0)
ax.set_xlabel('Number of credentials', fontsize=12)
ax.get_legend().remove()
ax.set_ylabel('Credentials per Second (TPS)', fontsize=12)
ax2.set_ylabel('Latency (s)', fontsize=12)
ax2.get_legend().remove()
plt.tight_layout()
# Shrink current axis's height by 10% on the bottom
box = ax.get_position()
ax.set_position([box.x0, box.y0 + box.height * 0.1,
                 box.width, box.height * 0.9])

# Put a legend below current axis
ax.legend(loc='upper center', bbox_to_anchor=(0.6, 0.6),
          fancybox=True, shadow=True, ncol=5)
ax2.legend(loc='upper center', bbox_to_anchor=(0.6, 0.5),
          fancybox=True, shadow=True, ncol=5)
plt.show()
fig.savefig('C:\\Users\\Eduardo\\Documents\\2022\\UNICAMP\\dissertation2022\\test\\Performance\\aries-ledgerlocal4to7nodes.jpg',
            format='jpeg',
            dpi=100,
            bbox_inches='tight')

# %% [markdown]
# ## ONLY HYPERLEDGER FABRIC WITH NODES INCREASE

# %%
df10 = pd.read_csv('C:\\Users\\Eduardo\\Documents\\2022\\UNICAMP\\dissertation2022\\test\\HyperledgerFabricMoreNodes\\grafh2nodes.csv')

# %%
df10
# Out:
#     txNumber  lat avg    tps  lat avg.1  tps.1  lat avg.2  tps.2  lat avg.3  \
# 0       1000     0.04  140.4       0.05  136.3       0.04  132.2       0.04
# 1       2000     0.06  144.4       0.05  140.2       0.05  140.9       0.07
# 2       3000     0.04  148.4       0.11  138.8       0.06  144.2       0.15
# 3       4000     0.05  152.0       0.05  152.5       0.06  147.9       0.06
# 4       5000     0.05  153.3       0.04  154.2       0.06  151.5       0.05
# 5       6000     0.05  157.8       0.05  157.8       0.06  155.6       0.06
# 6       7000     0.06  157.6       0.05  160.1       0.07  155.3       0.06
# 7       8000     0.06  163.3       0.07  161.7       0.08  161.0       0.08
# 8       9000     0.07  165.5       0.07  161.9       0.08  159.7       0.08
# 9      10000     0.07  163.5       0.06  169.5       0.08  165.0       0.07
# 10     11000     0.09  165.8       0.06  167.3       0.09  163.3       0.08
# ...

# %%
fig, ax = plt.subplots(figsize=(12,5))
h1=df10.iloc[0, 0]
#h2=df1.iloc[0, 3]
#h3=df1.iloc[0, 4]
#x='Hyperledger Aries Performance (number of threads ='+str(h1)+'), testnet: bcovrin (production)'
x='Hyperledger Fabric 2 and 3 nodes (levelDB and CouchDB), fixed input (sending 1000 tps, and 100 assets)'
ax.set_title(x)
ax2=ax.twinx()
df10.plot(x='txNumber', y='tps', ax=ax, alpha=0.8, color='black',label='TPS LevelDB 2n',linewidth=1.4)
df10.plot(x='txNumber', y='tps.1', ax=ax, alpha=0.8, color='black',label='TPS CouchDB 2n',linewidth=2.55)
df10.plot(x='txNumber', y='tps.2', ax=ax, alpha=0.8, color='black',label='TPS LevelDB 3n',linewidth=2.0)
df10.plot(x='txNumber', y='tps.3', ax=ax, alpha=0.8, color='black',label='TPS CouchDB 3n',linewidth=3.3)
#color='tab:green'
#ax2.set_ylabel('Max Latency (s)',color=color)
df10.plot(x='txNumber',y='lat avg',ax=ax2,linestyle = 'dotted',alpha=0.8, color='black',label='Lat LevelDB 2n',linewidth=1.4)

df10.plot(x='txNumber',y='lat avg.1',ax=ax2,linestyle = 'dashed',alpha=0.8, color='black',label='Lat CouchDB 2n',linewidth=2.55)
df10.plot(x='txNumber',y='lat avg.2',ax=ax2,linestyle = 'dotted',alpha=0.8, color='black',label='Lat LevelDB 3n',linewidth=2.0)
df10.plot(x='txNumber',y='lat avg.3',ax=ax2,linestyle = 'dashed',alpha=0.8, color='black',linewidth=3.3,label='Lat couchDB 3n')
ax.set_xlabel('Number of Transactions (txNumber)', fontsize=12)
ax.get_legend().remove()
ax.set_ylabel('TPS (Throughput)', fontsize=12)
ax2.set_ylabel('Latency (s)', fontsize=12)
ax2.get_legend().remove()
plt.tight_layout()
# Put a legend below current axis
ax.legend(loc='upper center', bbox_to_anchor=(0.66, 0.095),
          fancybox=True, shadow=True, ncol=5)
ax2.legend(loc='upper center', bbox_to_anchor=(0.669, 0.175),
          fancybox=True, shadow=True, ncol=5)
plt.show()
fig.savefig('C:\\Users\\Eduardo\\Documents\\2022\\UNICAMP\\dissertation2022\\test\\HyperledgerFabricMoreNodes\\fabric2and3nodes.jpg',
            format='jpeg',
            dpi=100,
            bbox_inches='tight')
